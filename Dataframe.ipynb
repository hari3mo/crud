# %%
import os
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

# %%
import random
import string
import uuid

# %%
accounts_path = 'files/Accounts List.csv'
leads_path = 'files/Leads List.csv'
accounts_df = pd.read_csv(accounts_path)
leads_df = pd.read_csv(leads_path)

# %%
accounts_df[accounts_df['Company Name'].isna()]
# Out:
#     Company Name  Company Revenue   Empoyee Head Count in millions  \
# 212          NaN           1200.0                             1800
#
#     Company Industry                               Company Specialities  \
# 212   Sporting Goods  Product Development, Design, Engineering, Cycl...
#
#        Company Type Company Location Country Name Company Location City  \
# 212  Privately Held                 United States              Waterloo
#
#     Company Location Timezone
# 212                       EST

# %%
accounts_duplicates = accounts_df[accounts_df['Company Name'].duplicated()]['Company Name']
accounts_df[accounts_df['Company Name'].isin(accounts_duplicates)].sort_values(by='Company Name', ascending=True).reset_index(drop=True)
# Out:
#                                        Company Name  Company Revenue  \
# 0                              E. & J. Gallo Winery           5000.0
# 1                              E. & J. Gallo Winery           5000.0
# 2                          East Carolina University            300.0
# 3                          East Carolina University            900.0
# 4                     Jared the Galleria of Jewelry           1100.0
# 5                     Jared the Galleria of Jewelry           1100.0
# 6                                       Lands'​ End           1500.0
# 7                                       Lands'​ End           1550.0
# 8                          TETRA Technologies, Inc.            800.0
# 9                          TETRA Technologies, Inc.            700.0
# 10                              The Hershey Company           8500.0
# 11                              The Hershey Company           8500.0
# 12  The Johns Hopkins University School of Medicine           3500.0
# 13  The Johns Hopkins University School of Medicine           4000.0
# 14                 Zakat, Tax and Customs Authority            600.0
# 15                 Zakat, Tax and Customs Authority            600.0
#
#      Empoyee Head Count in millions                 Company Industry  \
# 0                              6400                   Wine & Spirits
# 1                              6400           Beverage Manufacturing
# 2                              4200                 Higher Education
# 3                              4800                 Higher Education
# 4                              2400  Retail Luxury Goods and Jewelry
# 5                              2400  Retail Luxury Goods and Jewelry
# 6                              5000       Retail Apparel and Fashion
# 7                              5000                Apparel & Fashion
# 8                              1300                      Oil and Gas
# 9                              1500                      Oil and Gas
# 10                            16000                    Manufacturing
# 11                            16000                    Manufacturing
# 12                            20000        Hospitals and Health Care
# 13                            25000        Hospitals and Health Care
# 14                             1200        Government Administration
# 15                             1200        Government Administration
#
#                                  Company Specialities  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Arts and Sciences, Business, Education, Fine A...
# 3   Arts and Sciences, Business, Education, Fine A...
# 4                                                 NaN
# 5                                                 NaN
# 6   Retail, Direct Sales, Catalog, Digital, Appare...
# 7   Retail, Direct Sales, Catalog, Digital, Appare...
# 8   Early Production Facilities, Water Management ...
# 9   Early Production Facilities, Water Management ...
# 10                            Consumer Packaged Goods
# 11                            Consumer Packaged Goods
# 12                                                NaN
# 13                                                NaN
# 14                           Zakat, Tax, VAT, customs
# 15                           Zakat, Tax, VAT, customs
#
#                Company Type Company Location Country Name  \
# 0            Privately Held                 United States
# 1            Privately Held                 United States
# 2   Educational Institution                 United States
# 3               Educational                 United States
# 4            Public Company                 United States
# 5            Public Company                 United States
# 6            Public Company                 United States
# 7            Public Company                 United States
# 8            Public Company                 United States
# 9            Public Company                 United States
# 10           Public Company                 United States
# 11           Public Company                 United States
# 12  Educational Institution                 United States
# 13              Educational                 United States
# 14        Government Agency                  Saudi Arabia
# 15        Government Agency                  Saudi Arabia
#
#    Company Location City Company Location Timezone
# 0                Modesto                       EST
# 1                Modesto                       EST
# 2             Greenville                       EST
# 3             Greenville                       EST
# 4                  Akron                       EST
# 5                  Akron                       EST
# 6             Dodgeville                       EST
# 7             Dodgeville                       EST
# 8          The Woodlands                       EST
# 9          The Woodlands                       EST
# 10               Hershey                       EST
# 11               Hershey                       EST
# 12             Baltimore                       EST
# 13             Baltimore                       EST
# 14          Saudi Arabia                       AST
# 15                Riyadh                       AST

# %%
a_i = accounts_df[accounts_df['Company Name'].isna()].index
accounts_df.loc[a_i, 'Company Name'] = 'Trek Bicycle'

# %%
accounts_df =  accounts_df.sort_values(by='Company Name').reset_index(drop=True)
accounts_df['AccountID'] = range(accounts_df.shape[0])
accounts_df['AccountID'] = 1000 + (accounts_df.index * 10)
accounts_df['Company Revenue'] = accounts_df['Company Revenue'].astype(int)

# %%
accounts_df.rename(columns={' Empoyee Head Count in millions': 'Employee Head Count'}, inplace=True)
accounts_df.rename(columns={'Company Revenue': 'Company Revenue (in millions)'}, inplace=True)
accounts_df.drop_duplicates(subset='Company Name', keep='first', inplace=True)
accounts_df.reset_index(drop=True, inplace=True)

# %%
def generate_license_key():
    unique_id = uuid.uuid4().hex

    characters = string.ascii_uppercase + string.digits
    random_chars = ''.join(random.choice(characters) for i in range(4))

    license_key = (unique_id + random_chars)[:20]
    
    return license_key

# %%
# accounts_df['ClientID'] = [generate_license_key() for account in range(accounts_df.shape[0])]

# %%
accounts_df
# Out:
#                        Company Name  Company Revenue (in millions)  \
# 0                               -X-                           3800
# 1                   1st Source Bank                            300
# 2                            AMETEK                           6600
# 3                            ARASCO                           2200
# 4                           AVI-SPL                           1200
# ..                              ...                            ...
# 685              dormakaba Americas                           3200
# 686                              du                           3000
# 687  eXtra (United Electronics Co.)                           1100
# 688                          geidea                            200
# 689  school-board-of-broward-county                           9000
#
#      Employee Head Count                       Company Industry  \
# 0                  12000                        Food Production
# 1                   1150                                Banking
# 2                  21500  Electrical & Electronic Manufacturing
# 3                   4300                        Food Production
# 4                   2200          IT Services and IT Consulting
# ..                   ...                                    ...
# 685                 9400           Wholesale Building Materials
# 686                 2000                     Telecommunications
# 687                 2000                                 Retail
# 688                 1200                     Financial Services
# 689                31000      Education Administration Programs
#
#                                   Company Specialities    Company Type  \
# 0                                                  NaN  Public Company
# 1    Retail Banking, Private Banking, Business Bank...  Public Company
# 2                                                  NaN  Public Company
# 3    Animal Feed Manufacturing, Food Manufacturing,...  Privately Held
# 4    AV Systems Integration, Video Communications, ...  Privately Held
# ..                                                 ...             ...
# 685  Door Hardware, Automatic/Revolving Doors, Glas...  Public Company
# 686  Telecommunication, Media, Advertising, Technol...  Public Company
# 687  After Sales Services, consumer goods, customer...  Public Company
# 688  Point of Sale, payments , applications, Digita...  Privately Held
# 689                                                NaN     Educational
#
#     Company Location Country Name Company Location City  \
# 0                   United States                   NaN
# 1                   United States            South Bend
# 2                   United States                Berwyn
# 3                    Saudi Arabia                Riyadh
# 4                   United States                 Tampa
# ..                            ...                   ...
# 685                 United States          Indianapolis
# 686          United Arab Emirates                 Dubai
# 687                  Saudi Arabia             Al-Khobar
# 688                  Saudi Arabia                Riyadh
# 689                 United States       Fort Lauderdale
#
#     Company Location Timezone  AccountID
# 0                         EST       1000
# 1                         EST       1010
# 2                         EST       1020
# 3                         AST       1030
# 4                         EST       1040
# ..                        ...        ...
# 685                       EST       7930
# 686                       GST       7940
# 687                       AST       7950
# 688                       AST       7960
# 689                       EST       7970
#
# [690 rows x 10 columns]

# %%
# def generate_ids(group):
#     group['LeadID'] = range(100000, 100000 + 10 * len(group), 10)
#     return group
    
# leads_df = leads_df.groupby('Company').apply(generate_ids).reset_index(drop=True)

# %%
leads_df = pd.merge(leads_df, accounts_df[['Company Name', 'AccountID']], left_on='Company', right_on='Company Name')
leads_df.drop(columns='Company Name', inplace=True)

# %%
leads_df['LeadID'] = np.arange(leads_df.shape[0])
leads_df['LeadID'] = 100000 + leads_df.index * 10

# %%
leads_df
# Out:
#                        Company  \
# 0    American Chemical Society
# 1    American Chemical Society
# 2    American Chemical Society
# 3                   ArisGlobal
# 4                   ArisGlobal
# 5                   ArisGlobal
# 6   Armstrong World Industries
# 7   Armstrong World Industries
# 8   Armstrong World Industries
# 9                Fitch Ratings
# 10               Fitch Ratings
# 11               Fitch Ratings
# 12              Irvine Company
# 13              Irvine Company
# 14              Irvine Company
# 15         National Geographic
# 16          Shure Incorporated
# 17          Shure Incorporated
# 18          Shure Incorporated
# 19          Shure Incorporated
# 20   Evoqua Water Technologies
# 21   Evoqua Water Technologies
# 22             SS&C Intralinks
# 23             SS&C Intralinks
# 24             SS&C Intralinks
# 25        Phibro Animal Health
# 26                     Buckman
# 27             Tennant Company
# 28        S&C Electric Company
# 29        S&C Electric Company
# 30        S&C Electric Company
# 31            EMD Serono, Inc.
# 32          Simpson Strong-Tie
# 33          Simpson Strong-Tie
# 34          Simpson Strong-Tie
# 35              Avanos Medical
# 36              Avanos Medical
# 37              Avanos Medical
# 38      Hollister Incorporated
# 39      Hollister Incorporated
# 40      Hollister Incorporated
#
#                                              Position   First Name  Last Name  \
# 0           Director, Technology Strategy & Execution     Jennifer      Arndt
# 1   Director of Product Development and Solutions ...     Mitchell      Bakos
# 2   Senior Director & Chief of Staff, Product Stra...      Jessica     Rucker
# 3                   IT Director at ArisGlobal Company         Luka  Sustarsic
# 4                       Vice President, IT Operations       Darren   Newbould
# 5                                 Director Technology         Juby      Rajan
# 6                 Director of Information Technology        Jermey          M
# 7                         Senior Director, Technology      Micheal     Lorenz
# 8                     Director - Business Development          Tom   Stafford
# 9              Senior Director, Technology Operations         Mike     Brooks
# 10                Director of Information Technology     Geraldine     Foster
# 11                Director Of Information Technology       Micheal     Gordon
# 12                           Chief Technology Officer          Abe       Wong
# 13             Senior Director, Technology Enablement         Lisa     Larkin
# 14           Vice President,Technology and Innovation          Tim    McClain
# 15                           Chief Technology Officer        Jason   Southern
# 16  Executive Vice President & Chief Technology Of...        Sameh      Sabet
# 17   Senior Vice President, Chief Information Officer        Robin       Lane
# 18                 Senior Director, IT Infrastructure      Timothy      Lambe
# 19           Vice President of Corporate Development         Brian   Woodland
# 20              Director of Technology and Innovation      Richard      Joshi
# 21                Head of Technology and Applications      Xiangyi       Qiao
# 22          Vice President of Infrastructure Services          Tom   Catalano
# 23          Director of Technical Program Operations   Sandra-Jane    Mancini
# 24                      Head of Corporate Development  Luis Felipe    Bíscaro
# 25                          Chief Information Officer         Gary      Fling
# 26                              Chief Digital Officer           NM        Rao
# 27                          Chief Information Officer      Micheal    Mathews
# 28                          Chief Information Officer          Bob       King
# 29                            Chief Operating Officer         Jim     Johnson
# 30                                      VP Operations      Anthony     Bezina
# 31                              Senior Vice President         Gaby     Murphy
# 32                      EVP, Chief Technology Officer         Udit      Mehta
# 33     Vice President, IT Infrastructure & Operations         John       Meng
# 34          Information Technology Operations Manager         Kirk      Smith
# 35               Director of Global IT Infrastructure         Seth     Majors
# 36                          Chief Information Officer      Siobhan      Smyth
# 37                            Chief Executive Officer          Joe      Woody
# 38            Director, Global IT Business Solutions         Robin     Sacher
# 39            Vice President, Business Transformation      Stephen     Collum
# 40                                  President and COO      Abinash      Nayak
#
#                                     Email  AccountID  LeadID
# 0                          jarndt@acs.org       1390  100000
# 1                          mbakos@acs.org       1390  100010
# 2                         jrucker@acs.org       1390  100020
# 3               lsustarsic@arisglobal.com       1620  100030
# 4                dnewbould@arisglobal.com       1620  100040
# 5                   jrajan@arisglobal.com       1620  100050
# 6                 m@armstrongceilings.com       1640  100060
# 7    michael_lorenz@armstrongceilings.com       1640  100070
# 8         tstafford@armstrongceilings.com       1640  100080
# 9            mike.brooks@fitchratings.com       3410  100090
# 10      geraldine.foster@fitchratings.com       3410  100100
# 11        michael.gordon@fitchratings.com       3410  100110
# 12             abe.wong@irvinecompany.com       4300  100120
# 13              llarkin@irvinecompany.com       4300  100130
# 14             tmcclain@irvinecompany.com       4300  100140
# 15  jason.southern@nationalgeographic.com       5380  100150
# 16                       sabets@shure.com       6590  100160
# 17                        robin@shure.com       6590  100170
# 18                       lambet@shure.com       6590  100180
# 19                        brian@shure.com       6590  100190
# 20               richard.joshi@evoqua.com       3290  100200
# 21                xiangyi.qiao@evoqua.com       3290  100210
# 22            tom.catalano@intralinks.com       6320  100220
# 23      sandrajane.mancini@intralinks.com       6320  100230
# 24                  felipe@intralinks.com       6320  100240
# 25                    gary.fling@pahc.com       5870  100250
# 26                      nmrao@buckman.com       2160  100260
# 27                  michael@tennantco.com       7100  100270
# 28                     bob.king@sandc.com       6230  100280
# 29                          jim@sandc.com       6230  100290
# 30               anthony.bezina@sandc.com       6230  100300
# 31              gaby.murphy@emdserono.com       2990  100310
# 32                     udit@strongtie.com       6600  100320
# 33                    jmeng@strongtie.com       6600  100330
# 34               kirk.smith@strongtie.com       6600  100340
# 35                 seth.majors@avanos.com       1730  100350
# 36               siobhan.smyth@avanos.com       1730  100360
# 37                   joe.woody@avanos.com       1730  100370
# 38             robin.sachar@hollister.com       4050  100380
# 39           stephen.collum@hollister.com       4050  100390
# 40            abinash.nayak@hollister.com       4050  100400

# %%
accounts_df
# Out:
#                        Company Name  Company Revenue (in millions)  \
# 0                               -X-                           3800
# 1                   1st Source Bank                            300
# 2                            AMETEK                           6600
# 3                            ARASCO                           2200
# 4                           AVI-SPL                           1200
# ..                              ...                            ...
# 685              dormakaba Americas                           3200
# 686                              du                           3000
# 687  eXtra (United Electronics Co.)                           1100
# 688                          geidea                            200
# 689  school-board-of-broward-county                           9000
#
#      Employee Head Count                       Company Industry  \
# 0                  12000                        Food Production
# 1                   1150                                Banking
# 2                  21500  Electrical & Electronic Manufacturing
# 3                   4300                        Food Production
# 4                   2200          IT Services and IT Consulting
# ..                   ...                                    ...
# 685                 9400           Wholesale Building Materials
# 686                 2000                     Telecommunications
# 687                 2000                                 Retail
# 688                 1200                     Financial Services
# 689                31000      Education Administration Programs
#
#                                   Company Specialities    Company Type  \
# 0                                                  NaN  Public Company
# 1    Retail Banking, Private Banking, Business Bank...  Public Company
# 2                                                  NaN  Public Company
# 3    Animal Feed Manufacturing, Food Manufacturing,...  Privately Held
# 4    AV Systems Integration, Video Communications, ...  Privately Held
# ..                                                 ...             ...
# 685  Door Hardware, Automatic/Revolving Doors, Glas...  Public Company
# 686  Telecommunication, Media, Advertising, Technol...  Public Company
# 687  After Sales Services, consumer goods, customer...  Public Company
# 688  Point of Sale, payments , applications, Digita...  Privately Held
# 689                                                NaN     Educational
#
#     Company Location Country Name Company Location City  \
# 0                   United States                   NaN
# 1                   United States            South Bend
# 2                   United States                Berwyn
# 3                    Saudi Arabia                Riyadh
# 4                   United States                 Tampa
# ..                            ...                   ...
# 685                 United States          Indianapolis
# 686          United Arab Emirates                 Dubai
# 687                  Saudi Arabia             Al-Khobar
# 688                  Saudi Arabia                Riyadh
# 689                 United States       Fort Lauderdale
#
#     Company Location Timezone  AccountID
# 0                         EST       1000
# 1                         EST       1010
# 2                         EST       1020
# 3                         AST       1030
# 4                         EST       1040
# ..                        ...        ...
# 685                       EST       7930
# 686                       GST       7940
# 687                       AST       7950
# 688                       AST       7960
# 689                       EST       7970
#
# [690 rows x 10 columns]

# %%
client_df = pd.DataFrame(data=[[generate_license_key(), 'ERP Center, Inc.']], columns=[['ClientID', 'Subscriber']])
client_df
# Out:
#                ClientID        Subscriber
# 0  15f4d573ad6743fc8bbe  ERP Center, Inc.

# %%
accounts_df = accounts_df.set_index('AccountID').reset_index()
accounts_df
# Out:
#      AccountID                    Company Name  Company Revenue (in millions)  \
# 0         1000                             -X-                           3800
# 1         1010                 1st Source Bank                            300
# 2         1020                          AMETEK                           6600
# 3         1030                          ARASCO                           2200
# 4         1040                         AVI-SPL                           1200
# ..         ...                             ...                            ...
# 685       7930              dormakaba Americas                           3200
# 686       7940                              du                           3000
# 687       7950  eXtra (United Electronics Co.)                           1100
# 688       7960                          geidea                            200
# 689       7970  school-board-of-broward-county                           9000
#
#      Employee Head Count                       Company Industry  \
# 0                  12000                        Food Production
# 1                   1150                                Banking
# 2                  21500  Electrical & Electronic Manufacturing
# 3                   4300                        Food Production
# 4                   2200          IT Services and IT Consulting
# ..                   ...                                    ...
# 685                 9400           Wholesale Building Materials
# 686                 2000                     Telecommunications
# 687                 2000                                 Retail
# 688                 1200                     Financial Services
# 689                31000      Education Administration Programs
#
#                                   Company Specialities    Company Type  \
# 0                                                  NaN  Public Company
# 1    Retail Banking, Private Banking, Business Bank...  Public Company
# 2                                                  NaN  Public Company
# 3    Animal Feed Manufacturing, Food Manufacturing,...  Privately Held
# 4    AV Systems Integration, Video Communications, ...  Privately Held
# ..                                                 ...             ...
# 685  Door Hardware, Automatic/Revolving Doors, Glas...  Public Company
# 686  Telecommunication, Media, Advertising, Technol...  Public Company
# 687  After Sales Services, consumer goods, customer...  Public Company
# 688  Point of Sale, payments , applications, Digita...  Privately Held
# 689                                                NaN     Educational
#
#     Company Location Country Name Company Location City  \
# 0                   United States                   NaN
# 1                   United States            South Bend
# 2                   United States                Berwyn
# 3                    Saudi Arabia                Riyadh
# 4                   United States                 Tampa
# ..                            ...                   ...
# 685                 United States          Indianapolis
# 686          United Arab Emirates                 Dubai
# 687                  Saudi Arabia             Al-Khobar
# 688                  Saudi Arabia                Riyadh
# 689                 United States       Fort Lauderdale
#
#     Company Location Timezone
# 0                         EST
# 1                         EST
# 2                         EST
# 3                         AST
# 4                         EST
# ..                        ...
# 685                       EST
# 686                       GST
# 687                       AST
# 688                       AST
# 689                       EST
#
# [690 rows x 10 columns]

# %%
leads_df = leads_df.set_index('AccountID').reset_index().set_index('LeadID').reset_index()
leads_df
# Out:
#     LeadID  AccountID                     Company  \
# 0   100000       1390   American Chemical Society
# 1   100010       1390   American Chemical Society
# 2   100020       1390   American Chemical Society
# 3   100030       1620                  ArisGlobal
# 4   100040       1620                  ArisGlobal
# 5   100050       1620                  ArisGlobal
# 6   100060       1640  Armstrong World Industries
# 7   100070       1640  Armstrong World Industries
# 8   100080       1640  Armstrong World Industries
# 9   100090       3410               Fitch Ratings
# 10  100100       3410               Fitch Ratings
# 11  100110       3410               Fitch Ratings
# 12  100120       4300              Irvine Company
# 13  100130       4300              Irvine Company
# 14  100140       4300              Irvine Company
# 15  100150       5380         National Geographic
# 16  100160       6590          Shure Incorporated
# 17  100170       6590          Shure Incorporated
# 18  100180       6590          Shure Incorporated
# 19  100190       6590          Shure Incorporated
# 20  100200       3290   Evoqua Water Technologies
# 21  100210       3290   Evoqua Water Technologies
# 22  100220       6320             SS&C Intralinks
# 23  100230       6320             SS&C Intralinks
# 24  100240       6320             SS&C Intralinks
# 25  100250       5870        Phibro Animal Health
# 26  100260       2160                     Buckman
# 27  100270       7100             Tennant Company
# 28  100280       6230        S&C Electric Company
# 29  100290       6230        S&C Electric Company
# 30  100300       6230        S&C Electric Company
# 31  100310       2990            EMD Serono, Inc.
# 32  100320       6600          Simpson Strong-Tie
# 33  100330       6600          Simpson Strong-Tie
# 34  100340       6600          Simpson Strong-Tie
# 35  100350       1730              Avanos Medical
# 36  100360       1730              Avanos Medical
# 37  100370       1730              Avanos Medical
# 38  100380       4050      Hollister Incorporated
# 39  100390       4050      Hollister Incorporated
# 40  100400       4050      Hollister Incorporated
#
#                                              Position   First Name  Last Name  \
# 0           Director, Technology Strategy & Execution     Jennifer      Arndt
# 1   Director of Product Development and Solutions ...     Mitchell      Bakos
# 2   Senior Director & Chief of Staff, Product Stra...      Jessica     Rucker
# 3                   IT Director at ArisGlobal Company         Luka  Sustarsic
# 4                       Vice President, IT Operations       Darren   Newbould
# 5                                 Director Technology         Juby      Rajan
# 6                 Director of Information Technology        Jermey          M
# 7                         Senior Director, Technology      Micheal     Lorenz
# 8                     Director - Business Development          Tom   Stafford
# 9              Senior Director, Technology Operations         Mike     Brooks
# 10                Director of Information Technology     Geraldine     Foster
# 11                Director Of Information Technology       Micheal     Gordon
# 12                           Chief Technology Officer          Abe       Wong
# 13             Senior Director, Technology Enablement         Lisa     Larkin
# 14           Vice President,Technology and Innovation          Tim    McClain
# 15                           Chief Technology Officer        Jason   Southern
# 16  Executive Vice President & Chief Technology Of...        Sameh      Sabet
# 17   Senior Vice President, Chief Information Officer        Robin       Lane
# 18                 Senior Director, IT Infrastructure      Timothy      Lambe
# 19           Vice President of Corporate Development         Brian   Woodland
# 20              Director of Technology and Innovation      Richard      Joshi
# 21                Head of Technology and Applications      Xiangyi       Qiao
# 22          Vice President of Infrastructure Services          Tom   Catalano
# 23          Director of Technical Program Operations   Sandra-Jane    Mancini
# 24                      Head of Corporate Development  Luis Felipe    Bíscaro
# 25                          Chief Information Officer         Gary      Fling
# 26                              Chief Digital Officer           NM        Rao
# 27                          Chief Information Officer      Micheal    Mathews
# 28                          Chief Information Officer          Bob       King
# 29                            Chief Operating Officer         Jim     Johnson
# 30                                      VP Operations      Anthony     Bezina
# 31                              Senior Vice President         Gaby     Murphy
# 32                      EVP, Chief Technology Officer         Udit      Mehta
# 33     Vice President, IT Infrastructure & Operations         John       Meng
# 34          Information Technology Operations Manager         Kirk      Smith
# 35               Director of Global IT Infrastructure         Seth     Majors
# 36                          Chief Information Officer      Siobhan      Smyth
# 37                            Chief Executive Officer          Joe      Woody
# 38            Director, Global IT Business Solutions         Robin     Sacher
# 39            Vice President, Business Transformation      Stephen     Collum
# 40                                  President and COO      Abinash      Nayak
#
#                                     Email
# 0                          jarndt@acs.org
# 1                          mbakos@acs.org
# 2                         jrucker@acs.org
# 3               lsustarsic@arisglobal.com
# 4                dnewbould@arisglobal.com
# 5                   jrajan@arisglobal.com
# 6                 m@armstrongceilings.com
# 7    michael_lorenz@armstrongceilings.com
# 8         tstafford@armstrongceilings.com
# 9            mike.brooks@fitchratings.com
# 10      geraldine.foster@fitchratings.com
# 11        michael.gordon@fitchratings.com
# 12             abe.wong@irvinecompany.com
# 13              llarkin@irvinecompany.com
# 14             tmcclain@irvinecompany.com
# 15  jason.southern@nationalgeographic.com
# 16                       sabets@shure.com
# 17                        robin@shure.com
# 18                       lambet@shure.com
# 19                        brian@shure.com
# 20               richard.joshi@evoqua.com
# 21                xiangyi.qiao@evoqua.com
# 22            tom.catalano@intralinks.com
# 23      sandrajane.mancini@intralinks.com
# 24                  felipe@intralinks.com
# 25                    gary.fling@pahc.com
# 26                      nmrao@buckman.com
# 27                  michael@tennantco.com
# 28                     bob.king@sandc.com
# 29                          jim@sandc.com
# 30               anthony.bezina@sandc.com
# 31              gaby.murphy@emdserono.com
# 32                     udit@strongtie.com
# 33                    jmeng@strongtie.com
# 34               kirk.smith@strongtie.com
# 35                 seth.majors@avanos.com
# 36               siobhan.smyth@avanos.com
# 37                   joe.woody@avanos.com
# 38             robin.sachar@hollister.com
# 39           stephen.collum@hollister.com
# 40            abinash.nayak@hollister.com

# %%
# engine = create_engine('mysql+pymysql://root:00203053@localhost:3306/CRMContacts')
# engine = create_engine('mysql+pymysql://erpcrm:Erpcrmpass1!@aws-erp.cxugcosgcicf.us-east-2.rds.amazonaws.com:3306/erpcrmdb')
# accounts_df.to_sql('Accounts', con=engine, if_exists='replace', index=False)
# leads_df.to_sql('Leads', con=engine, if_exists='replace', index=False)

# %%
accounts_df.to_csv('files/accounts.csv', index=False)
leads_df.to_csv('files/leads.csv', index=False)

# %%
print(1)
# Out:
# 1
