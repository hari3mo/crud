# %%
# %run dataframe.ipynb

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, Integer, String, Text

# %%
support_ticket_df = pd.DataFrame(columns=['TicketID', 'AccountID', 'ContactID', 'Issue', 'Status', 'Priority', 'DateCreated', 'DateResolved'])
orders_df = pd.DataFrame(columns=['OrderID', 'AccountID', 'OrderDate', 'TotalAmount', 'Status'])
order_details_df = pd.DataFrame(columns=['OrderDetailID', 'OrderID', 'Quantity', 'Price', 'Discount'])

# %%
order_details_df
# Out:
# Empty DataFrame
# Columns: [OrderDetailID, OrderID, Quantity, Price, Discount]
# Index: []

# %%
client_df = pd.DataFrame(data=[[generate_license_key(), 'ERP Center, Inc.']], columns=['ClientID', 'Subscriber'])
client_df
# Out:
#                ClientID        Subscriber
# 0  dce51b2a6c0c4b5781f6  ERP Center, Inc.

# %%
orders_df
# Out:
# Empty DataFrame
# Columns: [OrderID, AccountID, OrderDate, TotalAmount, Status]
# Index: []

# %%
support_ticket_df
# Out:
# Empty DataFrame
# Columns: [TicketID, AccountID, ContactID, Issue, Status, Priority, DateCreated, DateResolved]
# Index: []

# %%
# engine = create_engine('mysql+pymysql://erpcrm:Erpcrmpass1!@aws-erp.cxugcosgcicf.us-east-2.rds.amazonaws.com:3306/erpcrmdb')

# leads_df.to_sql('Leads', con=engine, if_exists='replace', index=False, dtype={'LeadID': Integer, 'AccountID': Integer})

# support_ticket_df.to_sql('SupportTickets', con=engine, if_exists='replace', index=False, dtype={'TicketID': Integer, 'AccountID': Integer, 'ContactID': Integer, 
#                             'Issue': Text, 'Status': String(100), 'DateCreated': String(10), 'DateResolved': String(10), 'Priority': String(50)})

# order_details_df.to_sql('OrderDetails', con=engine, if_exists='replace', index=False, dtype={'Quantity': Integer, 'OrderDetailID': Integer,
#                             'OrderID': Integer, 'Price': Integer, 'Discount': Integer})

# orders_df.to_sql('Orders', con=engine, if_exists='replace', index=False, dtype={'OrderID': Integer, 'AccountID': Integer, 'OrderDate': String(10), 
#                             'TotalAmount': Integer, 'Status': String(100)})

# accounts_df.to_sql('Accounts', con=engine, if_exists='replace', index=False, dtype={'AccountID': Integer, 'Company Revenue (in millions)': Integer, 
#                             'Employee Head Count': Integer})

# client_df.to_sql('Clients', if_exists='replace', con=engine, index=False, dtype={'ClientID': String(20), 'Subscriber': String(50)})

# %%
# pd.read_sql('SELECT * FROM Accounts', con=engine)
# Out:
#      AccountID                       Company Name  \
# 0         1000                    NCH Corporation
# 1         1010  Sammons Financial Group Companies
# 2         1020           Lexington Medical Center
# 3         1030                           QuikTrip
# 4         1040                          Chargebee
# ..         ...                                ...
# 685       7930  The Lane Construction Corporation
# 686       7940                     Prohealth-care
# 687       7950                         Abt Global
# 688       7960                               BORN
# 689       7970     school-board-of-broward-county
#
#      Company Revenue (in millions)  Employee Head Count  \
# 0                             6000                 8500
# 1                              468                 1300
# 2                             3800                 8000
# 3                             9200                31000
# 4                              124                 1110
# ..                             ...                  ...
# 685                           2200                 5200
# 686                            900                 4000
# 687                            800                 3000
# 688                            600                 1800
# 689                           9000                31000
#
#                       Company Industry  \
# 0                            Chemicals
# 1                   Financial Services
# 2               Hospital & Health Care
# 3                               Retail
# 4                   Financial Services
# ..                                 ...
# 685                       Construction
# 686          Hospitals and Health Care
# 687                  Research Services
# 688      IT Services and IT Consulting
# 689  Education Administration Programs
#
#                                   Company Specialities    Company Type  \
# 0    Production Chemicals/Manufacturing, Commercial...  Privately Held
# 1                                   Financial Services  Privately Held
# 2    Heart Center, Women's Services, Cancer Center,...       Nonprofit
# 3                                                 None  Privately Held
# 4    Recurring Billing, Subscription Management, Pa...  Privately Held
# ..                                                 ...             ...
# 685  Public-Private Partnerships, Design-Build, Hea...  Privately Held
# 686                                               None      Non Profit
# 687  research, consulting, technical assistance, da...  Privately Held
# 688  ecommerce, digital, creative, cms, technology,...  Public Company
# 689                                               None     Educational
#
#     Company Location Country Name Company Location City  \
# 0                   United States                Irving
# 1                   United States       West Des Moines
# 2                   United States         West Columbia
# 3                   United States                 Tulsa
# 4                   United States         San Francisco
# ..                            ...                   ...
# 685                 United States              Cheshire
# 686                 United States              Waukesha
# 687                 United States             Rockville
# 688                 United States              New York
# 689                 United States       Fort Lauderdale
#
#     Company Location Timezone
# 0                         EST
# 1                         EST
# 2                         EST
# 3                         EST
# 4                         EST
# ..                        ...
# 685                       EST
# 686                       CST
# 687                       EST
# 688                       EST
# 689                       EST
#
# [690 rows x 10 columns]
