# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine

# %%
accounts_path = 'accounts.csv'
leads_path = 'leads.csv'
accounts_df = pd.read_csv(accounts_path)
leads_df = pd.read_csv(leads_path)

# %%
support_ticket_df = pd.DataFrame(columns=['TicketID', 'AccountID', 'ContactID', 'Issue', 'Status', 'Priority', 'Date Created', 'Date Resolved'])
orders_df = pd.DataFrame(columns=['OrderID', 'AccountID', 'Order Date', 'Total Amount', 'Status'])
order_details_df = pd.DataFrame(columns=['OrderDetailID', 'OrderID', 'ProductID', 'Quantity', 'Price', 'Discount'])

# %%
support_ticket_df
# Out:
# Empty DataFrame
# Columns: [TicketID, AccountID, ContactID, Issue, Status, Priority, Date Created, Date Resolved]
# Index: []

# %%
orders_df
# Out:
# Empty DataFrame
# Columns: [OrderID, AccountID, Order Date, Total Amount, Status]
# Index: []

# %%
order_details_df
# Out:
# Empty DataFrame
# Columns: [OrderDetailID, OrderID, ProductID, Quantity, Price, Discount]
# Index: []

# %%
leads_df
# Out:
#                        Company  \
# 0    American Chemical Society
# 1    American Chemical Society
# 2    American Chemical Society
# 3                   ArisGlobal
# 4                   ArisGlobal
# 5                   ArisGlobal
# 6   Armstrong World Industries
# 7   Armstrong World Industries
# 8   Armstrong World Industries
# 9                Fitch Ratings
# 10               Fitch Ratings
# 11               Fitch Ratings
# 12              Irvine Company
# 13              Irvine Company
# 14              Irvine Company
# 15         National Geographic
# 16          Shure Incorporated
# 17          Shure Incorporated
# 18          Shure Incorporated
# 19          Shure Incorporated
# 20   Evoqua Water Technologies
# 21   Evoqua Water Technologies
# 22             SS&C Intralinks
# 23             SS&C Intralinks
# 24             SS&C Intralinks
# 25        Phibro Animal Health
# 26                     Buckman
# 27             Tennant Company
# 28        S&C Electric Company
# ...

# %%
engine = create_engine('mysql+pymysql://erpcrm:Erpcrmpass1!@aws-erp.cxugcosgcicf.us-east-2.rds.amazonaws.com:3306/erpcrmdb')
support_ticket_df.to_sql('Support Tickets', con=engine, if_exists='replace', index=False,)
orders_df.to_sql('Orders', con=engine, if_exists='replace', index=False)
order_details_df.to_sql('Order Details', con=engine, if_exists='replace', index=False)
accounts_df.to_sql('Accounts', con=engine, if_exists='replace', index=False)
leads_df.to_sql('Leads', con=engine, if_exists='replace', index=False)
# Out:
# 41
