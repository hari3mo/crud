# %%
import os
import numpy as np
import pandas as pd
from sqlalchemy import create_engine

# %%
import random
import string
import uuid

# %%
accounts_path = 'files/Accounts List.csv'
leads_path = 'files/Leads List.csv'
accounts_df = pd.read_csv(accounts_path)
leads_df = pd.read_csv(leads_path)

# %%
accounts_df[accounts_df['Company Name'].isna()]
# Out:
#     Company Name Company Revenue in millions   Empoyee Head Count  \
# 212          NaN                        1200               1800.0
#
#     Company Industry                               Company Specialities  \
# 212   Sporting Goods  Product Development, Design, Engineering, Cycl...
#
#        Company Type Company Location Country Name Company Location City  \
# 212  Privately Held                 United States              Waterloo
#
#     Company Location Timezone
# 212                       EST

# %%
accounts_duplicates = accounts_df[accounts_df['Company Name'].duplicated()]['Company Name']
accounts_df[accounts_df['Company Name'].isin(accounts_duplicates)].sort_values(by='Company Name', ascending=True).reset_index(drop=True)
# Out:
#                                        Company Name  \
# 0                              E. & J. Gallo Winery
# 1                              E. & J. Gallo Winery
# 2                          East Carolina University
# 3                          East Carolina University
# 4                     Jared the Galleria of Jewelry
# 5                     Jared the Galleria of Jewelry
# 6                                       Lands'​ End
# 7                                       Lands'​ End
# 8                            STADA Emerging Markets
# 9                            STADA Emerging Markets
# 10                                           STERIS
# 11                                           STERIS
# 12                         TETRA Technologies, Inc.
# 13                         TETRA Technologies, Inc.
# 14                              The Hershey Company
# 15                              The Hershey Company
# 16  The Johns Hopkins University School of Medicine
# 17  The Johns Hopkins University School of Medicine
# 18                                 Webasto Americas
# 19                                 Webasto Americas
# 20                 Zakat, Tax and Customs Authority
# 21                 Zakat, Tax and Customs Authority
#
#    Company Revenue in millions   Empoyee Head Count  \
# 0                         5000               6400.0
# 1                         5000               6400.0
# 2                          900               4800.0
# 3                          300               4200.0
# 4                         1100               2400.0
# 5                         1100               2400.0
# 6                         1550               5000.0
# 7                         1500               5000.0
# 8                         1500               5000.0
# 9                         1000               3000.0
# 10                        3000               8000.0
# 11                        3000              12000.0
# 12                         800               1300.0
# 13                         700               1500.0
# 14                        8500              16000.0
# 15                        8500              16000.0
# 16                        3500              20000.0
# 17                        4000              25000.0
# 18                        1000               3000.0
# 19                        3000              10000.0
# 20                         600               1200.0
# 21                         600               1200.0
#
#                    Company Industry  \
# 0                    Wine & Spirits
# 1            Beverage Manufacturing
# 2                  Higher Education
# 3                  Higher Education
# 4   Retail Luxury Goods and Jewelry
# 5   Retail Luxury Goods and Jewelry
# 6                 Apparel & Fashion
# 7        Retail Apparel and Fashion
# 8      Pharmaceutical Manufacturing
# 9      Pharmaceutical Manufacturing
# 10  Medical Equipment Manufacturing
# 11  Medical Equipment Manufacturing
# 12                      Oil and Gas
# 13                      Oil and Gas
# 14                    Manufacturing
# 15                    Manufacturing
# 16        Hospitals and Health Care
# 17        Hospitals and Health Care
# 18      Motor Vehicle Manufacturing
# 19      Motor Vehicle Manufacturing
# 20        Government Administration
# 21        Government Administration
#
#                                  Company Specialities  \
# 0                                                 NaN
# 1                                                 NaN
# 2   Arts and Sciences, Business, Education, Fine A...
# 3   Arts and Sciences, Business, Education, Fine A...
# 4                                                 NaN
# 5                                                 NaN
# 6   Retail, Direct Sales, Catalog, Digital, Appare...
# 7   Retail, Direct Sales, Catalog, Digital, Appare...
# 8                                                 NaN
# 9                                                 NaN
# 10  infection prevention, contamination control, s...
# 11  Procedure Ready, Instrument Repair, Surgical D...
# 12  Early Production Facilities, Water Management ...
# 13  Early Production Facilities, Water Management ...
# 14                            Consumer Packaged Goods
# 15                            Consumer Packaged Goods
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                           Zakat, Tax, VAT, customs
# 21                           Zakat, Tax, VAT, customs
#
#                Company Type Company Location Country Name  \
# 0            Privately Held                 United States
# 1            Privately Held                 United States
# 2               Educational                 United States
# 3   Educational Institution                 United States
# 4            Public Company                 United States
# 5            Public Company                 United States
# 6            Public Company                 United States
# 7            Public Company                 United States
# 8            Public Company          United Arab Emirates
# 9            Public Company          United Arab Emirates
# 10           Public Company                 United States
# 11           Public Company                 United States
# 12           Public Company                 United States
# 13           Public Company                 United States
# 14           Public Company                 United States
# 15           Public Company                 United States
# 16  Educational Institution                 United States
# 17              Educational                 United States
# 18           Privately Held                 United States
# 19           Privately Held                 United States
# 20        Government Agency                  Saudi Arabia
# 21        Government Agency                  Saudi Arabia
#
#     Company Location City Company Location Timezone
# 0                 Modesto                       EST
# 1                 Modesto                       EST
# 2              Greenville                       EST
# 3              Greenville                       EST
# 4                   Akron                       EST
# 5                   Akron                       EST
# 6              Dodgeville                       EST
# 7              Dodgeville                       EST
# 8   Dubai Healthcare City                       GST
# 9   Dubai Healthcare City                       GST
# 10                 Mentor                       EST
# 11             Birmingham                       EST
# 12          The Woodlands                       EST
# 13          The Woodlands                       EST
# 14                Hershey                       EST
# 15                Hershey                       EST
# 16              Baltimore                       EST
# 17              Baltimore                       EST
# 18           Auburn Hills                       EST
# 19           Auburn Hills                       EST
# 20           Saudi Arabia                       AST
# 21                 Riyadh                       AST

# %%
a_i = accounts_df[accounts_df['Company Name'].isna()].index
accounts_df.loc[a_i, 'Company Name'] = 'Trek Bicycle'

# %%
accounts_df = accounts_df.rename(columns={' Empoyee Head Count': 'EmployeeHeadCount', 'Company Revenue': 'CompanyRevenue', 'Company Name': 'CompanyName', 'Company Industry': 'CompanyIndustry',
                            'Company Type': 'CompanyType', 'Company Location Country Name': 'Country', 'Company Location City': 'City', 'Company Location Timezone': 'Timezone',
                            'Company Specialities': 'CompanySpecialties'})

# %%
accounts_df
# Out:
#                                             CompanyName  \
# 0                                       NCH Corporation
# 1                     Sammons Financial Group Companies
# 2                              Lexington Medical Center
# 3                                              QuikTrip
# 4                                             Chargebee
# ...                                                 ...
# 1162                                          Andalusco
# 1163  Mohamed Naser Al-Sayer & Sons Establishment Co...
# 1164                      Grace Community Church School
# 1165                                        Farhangsara
# 1166                                            Qiaubec
#
#      Company Revenue in millions  EmployeeHeadCount  \
# 0                           6000             8500.0
# 1                            468             1300.0
# 2                           3800             8000.0
# 3                           9200            31000.0
# 4                          124.4             1110.0
# ...                          ...                ...
# 1162                          50              150.0
# 1163                         100              300.0
# 1164                        15.9              100.0
# 1165                          30              100.0
# 1166                          70              200.0
#
#                    CompanyIndustry  \
# 0                        Chemicals
# 1               Financial Services
# 2           Hospital & Health Care
# 3                           Retail
# 4               Financial Services
# ...                            ...
# 1162  Wholesale Building Materials
# 1163                    Automotive
# 1164        Religious Institutions
# 1165           Retail Art Supplies
# 1166                     Education
#
#                                      CompanySpecialties     CompanyType  \
# 0     Production Chemicals/Manufacturing, Commercial...  Privately Held
# 1                                    Financial Services  Privately Held
# 2     Heart Center, Women's Services, Cancer Center,...       Nonprofit
# 3                                                   NaN  Privately Held
# 4     Recurring Billing, Subscription Management, Pa...  Privately Held
# ...                                                 ...             ...
# 1162                                                NaN  Public Company
# 1163                                                NaN             NaN
# 1164                                                NaN     Educational
# 1165                                                NaN  Public Company
# 1166                                                NaN     Educational
#
#             Country             City Timezone
# 0     United States           Irving      EST
# 1     United States  West Des Moines      EST
# 2     United States    West Columbia      EST
# 3     United States            Tulsa      EST
# 4     United States    San Francisco      EST
# ...             ...              ...      ...
# 1162        Morocco       Casablanca      WET
# 1163         Kuwait      Kuwait City      AST
# 1164  United States            Tyler      CST
# 1165           Iran           Tehran     IRST
# 1166         Canada      Quebec City      EST
#
# [1167 rows x 9 columns]

# %%
accounts_df =  accounts_df.sort_values(by='CompanyName').reset_index(drop=True)
accounts_df['AccountID'] = range(accounts_df.shape[0])
accounts_df['AccountID'] = 1000 + (accounts_df.index * 10)

# %%
accounts_df.drop_duplicates(subset='CompanyName', keep='first', inplace=True)
accounts_df.reset_index(drop=True, inplace=True)

# %%
raw_accounts = accounts_df.drop(columns='AccountID')
raw_accounts.to_csv('files/accounts_raw.csv', index=False)

# %%
raw_accounts
# Out:
#                                   CompanyName Company Revenue in millions  \
# 0                                         -X-                        3800
# 1                             1st Source Bank                         300
# 2     AAF International (American Air Filter)                         800
# 3                          AAW Pharma Medical                          80
# 4                                        AFIA                          80
# ...                                       ...                         ...
# 1151           eXtra (United Electronics Co.)                        1100
# 1152                                   geidea                         200
# 1153                  pSemi, A Murata Company                         300
# 1154           school-board-of-broward-county                        9000
# 1155                            wheatlandtube                         150
#
#       EmployeeHeadCount                               CompanyIndustry  \
# 0               12000.0                               Food Production
# 1                1150.0                                       Banking
# 2                2000.0  Renewable Energy Semiconductor Manufacturing
# 3                 300.0                  Pharmaceutical Manufacturing
# 4                 200.0               Food and Beverage Manufacturing
# ...                 ...                                           ...
# 1151             2000.0                                        Retail
# 1152             1200.0                            Financial Services
# 1153              800.0                   Semiconductor Manufacturing
# 1154            31000.0             Education Administration Programs
# 1155              600.0            Industrial Machinery Manufacturing
#
#                                      CompanySpecialties     CompanyType  \
# 0                                                   NaN  Public Company
# 1     Retail Banking, Private Banking, Business Bank...  Public Company
# 2     Clean Air Solutions, Healthcare Filtration Sol...  Privately Held
# 3                                                   NaN  Privately Held
# 4                                                   NaN  Privately Held
# ...                                                 ...             ...
# 1151  After Sales Services, consumer goods, customer...  Public Company
# 1152  Point of Sale, payments , applications, Digita...  Privately Held
# 1153  RF, Power management , Antenna tuning , Connec...  Privately Held
# 1154                                                NaN     Educational
# 1155                                                NaN  Privately Held
#
#             Country             City Timezone
# 0     United States              NaN      EST
# 1     United States       South Bend      EST
# 2     United States       Louisville      EST
# 3            Kuwait      Kuwait City      AST
# 4      Saudi Arabia           Jeddah      AST
# ...             ...              ...      ...
# 1151   Saudi Arabia        Al-Khobar      AST
# 1152   Saudi Arabia           Riyadh      AST
# 1153  United States        San Diego      PST
# 1154  United States  Fort Lauderdale      EST
# 1155  United States        Wheatland      EST
#
# [1156 rows x 9 columns]

# %%
def generate_license_key():
    unique_id = uuid.uuid4().hex

    characters = string.ascii_uppercase + string.digits
    random_chars = ''.join(random.choice(characters) for i in range(4))

    license = (unique_id + random_chars)[:20]
    
    return license

# %%
generate_license_key()
# Out:
# '3ad593aff9d6487ca47b'

# %%
# accounts_df['ClientID'] = [generate_license_key() for account in range(accounts_df.shape[0])]

# %%
accounts_df
# Out:
#                                   CompanyName Company Revenue in millions  \
# 0                                         -X-                        3800
# 1                             1st Source Bank                         300
# 2     AAF International (American Air Filter)                         800
# 3                          AAW Pharma Medical                          80
# 4                                        AFIA                          80
# ...                                       ...                         ...
# 1151           eXtra (United Electronics Co.)                        1100
# 1152                                   geidea                         200
# 1153                  pSemi, A Murata Company                         300
# 1154           school-board-of-broward-county                        9000
# 1155                            wheatlandtube                         150
#
#       EmployeeHeadCount                               CompanyIndustry  \
# 0               12000.0                               Food Production
# 1                1150.0                                       Banking
# 2                2000.0  Renewable Energy Semiconductor Manufacturing
# 3                 300.0                  Pharmaceutical Manufacturing
# 4                 200.0               Food and Beverage Manufacturing
# ...                 ...                                           ...
# 1151             2000.0                                        Retail
# 1152             1200.0                            Financial Services
# 1153              800.0                   Semiconductor Manufacturing
# 1154            31000.0             Education Administration Programs
# 1155              600.0            Industrial Machinery Manufacturing
#
#                                      CompanySpecialties     CompanyType  \
# 0                                                   NaN  Public Company
# 1     Retail Banking, Private Banking, Business Bank...  Public Company
# 2     Clean Air Solutions, Healthcare Filtration Sol...  Privately Held
# 3                                                   NaN  Privately Held
# 4                                                   NaN  Privately Held
# ...                                                 ...             ...
# 1151  After Sales Services, consumer goods, customer...  Public Company
# 1152  Point of Sale, payments , applications, Digita...  Privately Held
# 1153  RF, Power management , Antenna tuning , Connec...  Privately Held
# 1154                                                NaN     Educational
# 1155                                                NaN  Privately Held
#
#             Country             City Timezone  AccountID
# 0     United States              NaN      EST       1000
# 1     United States       South Bend      EST       1010
# 2     United States       Louisville      EST       1020
# 3            Kuwait      Kuwait City      AST       1030
# 4      Saudi Arabia           Jeddah      AST       1040
# ...             ...              ...      ...        ...
# 1151   Saudi Arabia        Al-Khobar      AST      12620
# 1152   Saudi Arabia           Riyadh      AST      12630
# 1153  United States        San Diego      PST      12640
# 1154  United States  Fort Lauderdale      EST      12650
# 1155  United States        Wheatland      EST      12660
#
# [1156 rows x 10 columns]

# %%
# def generate_ids(group):
#     group['LeadID'] = range(100000, 100000 + 10 * len(group), 10)
#     return group
    
# leads_df = leads_df.groupby('Company').apply(generate_ids).reset_index(drop=True)

# %%
leads_df = pd.merge(leads_df, accounts_df[['CompanyName', 'AccountID']], left_on='Company Name', right_on='CompanyName')
leads_df.drop(columns='Company Name', inplace=True)

# %%
leads_df['LeadID'] = np.arange(leads_df.shape[0])
leads_df['LeadID'] = 100000 + leads_df.index * 10

# %%
leads_df
# Out:
#                                   Position First Name  Last Name  \
# 0                Chief Information Officer        Bob       King
# 1                  Chief Operating Officer        Jim    Johnson
# 2                            VP Operations    Anthony     Bezina
# 3                Chief Information Officer       Adam       Kuta
# 4     Senior Director, Business Technology      Irene  Valentine
# ..                                     ...        ...        ...
# 543      Director, Application Development    Micheal       Carr
# 544                     Chief Data Officer     Rizwan     Tufail
# 545         Head Of Information Technology      Oytun      Gürün
# 546               Chief Technology Officer       Qais      Amori
# 547  Senior Information Technology Manager       Arif      Aijaz
#
#                              Email  Unnamed: 5  \
# 0               bob.king@sandc.com         NaN
# 1                    jim@sandc.com         NaN
# 2         anthony.bezina@sandc.com         NaN
# 3                 akuta@mybobs.com         NaN
# 4       irene.valentine@mybobs.com         NaN
# ..                             ...         ...
# 543            michael@kerzner.com         NaN
# 544    rizwan.tufail@purehealth.ae         NaN
# 545  oytun.gurun@addresshotels.com         NaN
# 546       qais.amori@almosafer.com         NaN
# 547         arif.aijaz@taqa.com.sa         NaN
#
#                              0 Results  Non - US Companies  \
# 0                    Dawn Foods Global                 NaN
# 1             Wyndham Hotels & Resorts                 NaN
# 2                           Razer Inc.                 NaN
# 3                    Briggs & Stratton                 NaN
# 4    Sammons Financial Group Companies                 NaN
# ..                                 ...                 ...
# 543                                NaN                 NaN
# 544                                NaN                 NaN
# 545                                NaN                 NaN
# 546                                NaN                 NaN
# 547                                NaN                 NaN
#
#                                            CompanyName  AccountID  LeadID
# 0                                 S&C Electric Company       9700  100000
# 1                                 S&C Electric Company       9700  100010
# 2                                 S&C Electric Company       9700  100020
# 3                             Bob's Discount Furniture       2700  100030
# 4                             Bob's Discount Furniture       2700  100040
# ..                                                 ...        ...     ...
# 543                              Kerzner International       6860  105430
# 544                                         PureHealth       9190  105440
# 545                           Address Hotels + Resorts       1270  105450
# 546                                          Almosafer       1650  105460
# 547  TAQA (Industrialization & Energy Services Comp...      10920  105470
#
# [548 rows x 10 columns]

# %%
accounts_df.at[accounts_df[accounts_df['CompanyName'] == 'school-board-of-broward-county'].index[0], 'CompanyName'] = 'School Board of Broward County'

# %%
# client_df = pd.DataFrame(data=[[generate_license_key(), 'ERP Center, Inc.']], columns=[['ClientID', 'Subscriber']])
# client_df

# %%
accounts_df = accounts_df.set_index('AccountID').reset_index()
accounts_df
# Out:
#       AccountID                              CompanyName  \
# 0          1000                                      -X-
# 1          1010                          1st Source Bank
# 2          1020  AAF International (American Air Filter)
# 3          1030                       AAW Pharma Medical
# 4          1040                                     AFIA
# ...         ...                                      ...
# 1151      12620           eXtra (United Electronics Co.)
# 1152      12630                                   geidea
# 1153      12640                  pSemi, A Murata Company
# 1154      12650           School Board of Broward County
# 1155      12660                            wheatlandtube
#
#      Company Revenue in millions  EmployeeHeadCount  \
# 0                           3800            12000.0
# 1                            300             1150.0
# 2                            800             2000.0
# 3                             80              300.0
# 4                             80              200.0
# ...                          ...                ...
# 1151                        1100             2000.0
# 1152                         200             1200.0
# 1153                         300              800.0
# 1154                        9000            31000.0
# 1155                         150              600.0
#
#                                    CompanyIndustry  \
# 0                                  Food Production
# 1                                          Banking
# 2     Renewable Energy Semiconductor Manufacturing
# 3                     Pharmaceutical Manufacturing
# 4                  Food and Beverage Manufacturing
# ...                                            ...
# 1151                                        Retail
# 1152                            Financial Services
# 1153                   Semiconductor Manufacturing
# 1154             Education Administration Programs
# 1155            Industrial Machinery Manufacturing
#
#                                      CompanySpecialties     CompanyType  \
# 0                                                   NaN  Public Company
# 1     Retail Banking, Private Banking, Business Bank...  Public Company
# 2     Clean Air Solutions, Healthcare Filtration Sol...  Privately Held
# 3                                                   NaN  Privately Held
# 4                                                   NaN  Privately Held
# ...                                                 ...             ...
# 1151  After Sales Services, consumer goods, customer...  Public Company
# 1152  Point of Sale, payments , applications, Digita...  Privately Held
# 1153  RF, Power management , Antenna tuning , Connec...  Privately Held
# 1154                                                NaN     Educational
# 1155                                                NaN  Privately Held
#
#             Country             City Timezone
# 0     United States              NaN      EST
# 1     United States       South Bend      EST
# 2     United States       Louisville      EST
# 3            Kuwait      Kuwait City      AST
# 4      Saudi Arabia           Jeddah      AST
# ...             ...              ...      ...
# 1151   Saudi Arabia        Al-Khobar      AST
# 1152   Saudi Arabia           Riyadh      AST
# 1153  United States        San Diego      PST
# 1154  United States  Fort Lauderdale      EST
# 1155  United States        Wheatland      EST
#
# [1156 rows x 10 columns]

# %%
leads_df = leads_df.set_index('AccountID').reset_index().set_index('LeadID').reset_index()
leads_df
# Out:
#      LeadID  AccountID                               Position First Name  \
# 0    100000       9700              Chief Information Officer        Bob
# 1    100010       9700                Chief Operating Officer        Jim
# 2    100020       9700                          VP Operations    Anthony
# 3    100030       2700              Chief Information Officer       Adam
# 4    100040       2700   Senior Director, Business Technology      Irene
# ..      ...        ...                                    ...        ...
# 543  105430       6860      Director, Application Development    Micheal
# 544  105440       9190                     Chief Data Officer     Rizwan
# 545  105450       1270         Head Of Information Technology      Oytun
# 546  105460       1650               Chief Technology Officer       Qais
# 547  105470      10920  Senior Information Technology Manager       Arif
#
#      Last Name                          Email  Unnamed: 5  \
# 0         King             bob.king@sandc.com         NaN
# 1      Johnson                  jim@sandc.com         NaN
# 2       Bezina       anthony.bezina@sandc.com         NaN
# 3         Kuta               akuta@mybobs.com         NaN
# 4    Valentine     irene.valentine@mybobs.com         NaN
# ..         ...                            ...         ...
# 543       Carr            michael@kerzner.com         NaN
# 544     Tufail    rizwan.tufail@purehealth.ae         NaN
# 545      Gürün  oytun.gurun@addresshotels.com         NaN
# 546      Amori       qais.amori@almosafer.com         NaN
# 547      Aijaz         arif.aijaz@taqa.com.sa         NaN
#
#                              0 Results  Non - US Companies  \
# 0                    Dawn Foods Global                 NaN
# 1             Wyndham Hotels & Resorts                 NaN
# 2                           Razer Inc.                 NaN
# 3                    Briggs & Stratton                 NaN
# 4    Sammons Financial Group Companies                 NaN
# ..                                 ...                 ...
# 543                                NaN                 NaN
# 544                                NaN                 NaN
# 545                                NaN                 NaN
# 546                                NaN                 NaN
# 547                                NaN                 NaN
#
#                                            CompanyName
# 0                                 S&C Electric Company
# 1                                 S&C Electric Company
# 2                                 S&C Electric Company
# 3                             Bob's Discount Furniture
# 4                             Bob's Discount Furniture
# ..                                                 ...
# 543                              Kerzner International
# 544                                         PureHealth
# 545                           Address Hotels + Resorts
# 546                                          Almosafer
# 547  TAQA (Industrialization & Energy Services Comp...
#
# [548 rows x 10 columns]

# %%
# engine = create_engine('mysql+pymysql://root:00203053@localhost:3306/CRMContacts')
# engine = create_engine('mysql+pymysql://erpcrm:Erpcrmpass1!@aws-erp.cxugcosgcicf.us-east-2.rds.amazonaws.com:3306/erpcrmdb')
# accounts_df.to_sql('Accounts', con=engine, if_exists='replace', index=False)
# leads_df.to_sql('Leads', con=engine, if_exists='replace', index=False)

# %%
accounts_df.to_csv('files/accounts.csv', index=False)
leads_df.to_csv('files/leads.csv', index=False)

# %%
pd.read_csv('files/accounts.csv')
# Out:
#       AccountID                              CompanyName  \
# 0          1000                                      -X-
# 1          1010                          1st Source Bank
# 2          1020  AAF International (American Air Filter)
# 3          1030                       AAW Pharma Medical
# 4          1040                                     AFIA
# ...         ...                                      ...
# 1151      12620           eXtra (United Electronics Co.)
# 1152      12630                                   geidea
# 1153      12640                  pSemi, A Murata Company
# 1154      12650           School Board of Broward County
# 1155      12660                            wheatlandtube
#
#      Company Revenue in millions  EmployeeHeadCount  \
# 0                           3800            12000.0
# 1                            300             1150.0
# 2                            800             2000.0
# 3                             80              300.0
# 4                             80              200.0
# ...                          ...                ...
# 1151                        1100             2000.0
# 1152                         200             1200.0
# 1153                         300              800.0
# 1154                        9000            31000.0
# 1155                         150              600.0
#
#                                    CompanyIndustry  \
# 0                                  Food Production
# 1                                          Banking
# 2     Renewable Energy Semiconductor Manufacturing
# 3                     Pharmaceutical Manufacturing
# 4                  Food and Beverage Manufacturing
# ...                                            ...
# 1151                                        Retail
# 1152                            Financial Services
# 1153                   Semiconductor Manufacturing
# 1154             Education Administration Programs
# 1155            Industrial Machinery Manufacturing
#
#                                      CompanySpecialties     CompanyType  \
# 0                                                   NaN  Public Company
# 1     Retail Banking, Private Banking, Business Bank...  Public Company
# 2     Clean Air Solutions, Healthcare Filtration Sol...  Privately Held
# 3                                                   NaN  Privately Held
# 4                                                   NaN  Privately Held
# ...                                                 ...             ...
# 1151  After Sales Services, consumer goods, customer...  Public Company
# 1152  Point of Sale, payments , applications, Digita...  Privately Held
# 1153  RF, Power management , Antenna tuning , Connec...  Privately Held
# 1154                                                NaN     Educational
# 1155                                                NaN  Privately Held
#
#             Country             City Timezone
# 0     United States              NaN      EST
# 1     United States       South Bend      EST
# 2     United States       Louisville      EST
# 3            Kuwait      Kuwait City      AST
# 4      Saudi Arabia           Jeddah      AST
# ...             ...              ...      ...
# 1151   Saudi Arabia        Al-Khobar      AST
# 1152   Saudi Arabia           Riyadh      AST
# 1153  United States        San Diego      PST
# 1154  United States  Fort Lauderdale      EST
# 1155  United States        Wheatland      EST
#
# [1156 rows x 10 columns]

# %%
leads = pd.DataFrame(columns=['ClientID'] + list(leads_df.columns) + ['DateCreated', 'DateModified']).rename(columns={'First Name': 'FirstName', 'Last Name': 'LastName'}).set_index('AccountID').reset_index().set_index('LeadID').reset_index()
leads
# Out:
# Empty DataFrame
# Columns: [LeadID, AccountID, ClientID, Position, FirstName, LastName, Email, Unnamed: 5, 0 Results, Non - US Companies, CompanyName, DateCreated, DateModified]
# Index: []

# %%
accounts = pd.DataFrame(columns=accounts_df.columns).set_index('AccountID').reset_index()
accounts
# Out:
# Empty DataFrame
# Columns: [AccountID, CompanyName, Company Revenue in millions, EmployeeHeadCount, CompanyIndustry, CompanySpecialties, CompanyType, Country, City, Timezone]
# Index: []

# %%
generate_license_key()
# Out:
# 'b08f69d4b574410da893'
