# %%
# %run dataframe.ipynb

# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine, text
from sqlalchemy import Table, Column, Integer, String, Text, insert, LargeBinary, Date

# %%
support_ticket_df = pd.DataFrame(columns=['TicketID', 'AccountID', 'ContactID', 'Issue', 'Status', 'Priority', 'DateCreated', 'DateResolved'])
orders_df = pd.DataFrame(columns=['OrderID', 'AccountID', 'OrderDate', 'TotalAmount', 'Status'])
order_details_df = pd.DataFrame(columns=['OrderDetailID', 'OrderID', 'Quantity', 'Price', 'Discount'])
users_df = pd.DataFrame(columns=['UserID', 'Email', 'PasswordHash', 'License', 'Client', 'ValidFrom', 'ValidTo'])
opportunities_df = pd.DataFrame(columns=['OpportunityID', 'AccountID', 'LeadID', 'ClientID', 'Opportunity', 'Value', 'Stage', 'CreationDate', 'CloseDate' ])

# %%
opportunities_df
# Out:
# Empty DataFrame
# Columns: [OpportunityID, AccountID, LeadID, ClientID, Opportunity, Value, Stage, CreationDate, CloseDate]
# Index: []

# %%
order_details_df
# Out:
# Empty DataFrame
# Columns: [OrderDetailID, OrderID, Quantity, Price, Discount]
# Index: []

# %%
'3a95d70c85864ab99603'
# Out:
# '3a95d70c85864ab99603'

# %%
client_df = pd.DataFrame(data=[['0', 'ERP Center, Inc.', '3a95d70c85864ab99603', '/images/3a95d70c85864ab99603.png', '00:00:0000', '00:00:0000']], columns=['ClientID', 'Client', 'License', 'Image', 'ValidFrom', 'ValidTo']) 
client_df
# Out:
#   ClientID            Client               License  \
# 0        0  ERP Center, Inc.  3a95d70c85864ab99603
#
#                               Image   ValidFrom     ValidTo
# 0  /images/3a95d70c85864ab99603.png  00:00:0000  00:00:0000

# %%
orders_df
# Out:
# Empty DataFrame
# Columns: [OrderID, AccountID, OrderDate, TotalAmount, Status]
# Index: []

# %%
support_ticket_df
# Out:
# Empty DataFrame
# Columns: [TicketID, AccountID, ContactID, Issue, Status, Priority, DateCreated, DateResolved]
# Index: []

# %%
engine = create_engine('mysql+pymysql://erpcrm:Erpcrmpass1!@erpcrmdb.cfg0ok8iismy.us-west-1.rds.amazonaws.com:3306/erpcrmdb')

# %%
#  ids = pd.read_sql("SELECT AccountID FROM Accounts", con=engine)
#  ids.empty

# %%
# leads_df.to_sql('Leads', con=engine, if_exists='replace', index=False, dtype={'LeadID': Integer, 'AccountID': Integer})

# support_ticket_df.to_sql('SupportTickets', con=engine, if_exists='replace', index=False, dtype={'TicketID': Integer, 'AccountID': Integer, 'ContactID': Integer, 
#                             'Issue': Text, 'Status': String(100), 'DateCreated': Date, 'DateResolved': Date, 'Priority': String(50)})

# order_details_df.to_sql('OrderDetails', con=engine, if_exists='replace', index=False, dtype={'Quantity': Integer, 'OrderDetailID': Integer,
#                             'OrderID': Integer, 'Price': Integer, 'Discount': Integer})

# orders_df.to_sql('Orders', con=engine, if_exists='replace', index=False, dtype={'OrderID': Integer, 'AccountID': Integer, 'OrderDate': Date, 
#                             'TotalAmount': Integer, 'Status': String(100)})

# accounts_df.to_sql('Accounts', con=engine, if_exists='replace', index=False, dtype={'AccountID': Integer, 'CompanyRevenue': Integer, 
#                             'EmployeeHeadCount': Integer, 'CompanyName': String(100), 'CompanyIndustry': String(100), 'CompanyType': String(50), 'Country': String(50),
#                             'City': String(50), 'Timezone': String(50)})

# client_df.to_sql('Clients', if_exists='replace', con=engine, index=False, dtype={'ClientID': Integer, 'Client': String(50), 'License': String(20), 'Image': String(255), 'ValidFrom': Date,
#                                                                                  'ValidTo': Date})

# users_df.to_sql('Users', if_exists='replace', con=engine, index=False, dtype={'UserID': Integer, 'Email': String(50), 'PasswordHash': String(255), 'License': String(20), 'Client': String(50), 
#                             'ValidFrom': Date, 'ValidTo': Date})

opportunities_df.to_sql('Opportunities', if_exists='replace', con=engine, index=False, dtype={'OpportunityID': Integer, 'AccountID': Integer, 'LeadID': Integer, 'ClientID': Integer, 'Opportunity': Text,
                                                                                              'Value': String(255), 'Stage': String(100), 'CreationDate': Date, 'CloseDate': Date})
# Out:
# 0

# %%
leads
# Out:
# Empty DataFrame
# Columns: [LeadID, AccountID, ClientID, Position, FirstName, LastName, Email, Unnamed: 5, CompanyName, DateCreated, DateModified]
# Index: []

# %%
# accounts.to_sql('Accounts', con=engine, if_exists='replace', index=False, dtype={'AccountID': Integer, 'CompanyRevenue': Integer, 
#                             'EmployeeHeadCount': Integer, 'CompanyName': String(100), 'CompanyIndustry': String(100), 'CompanyType': String(50), 'Country': String(50),
#                             'City': String(50), 'Timezone': String(50)})

# %%
# pd.read_sql('SELECT * FROM Accounts', con=engine)

# %%
accounts['AccountID'].empty
# Out:
# True

# %%
# for index, row in accounts_df.iterrows():
#     print(row.to_dict())

# %%
# %%timeit

# df = pd.read_sql('SELECT AccountID from Accounts', con=engine)
# if ids['AccountID'].empty:
#     next_id = 1000
# else:
#     next_id = (ids['AccountID'].max()) + 10

# %%
# %%timeit

# df = pd.read_sql('SELECT AccountID from Accounts', con=engine)
# if ids['AccountID'].empty:
#     next_id = 1000
# else:
#     next_id = (ids['AccountID'].iloc[-1]) + 10

# %%
leads
# Out:
# Empty DataFrame
# Columns: [LeadID, AccountID, ClientID, Position, FirstName, LastName, Email, Unnamed: 5, CompanyName, DateCreated, DateModified]
# Index: []

# %%
leads.drop(columns=['Unnamed: 5', 'DateCreated', 'DateModified'], inplace=True)

# %%
leads.to_sql('Leads', con=engine, if_exists='replace', index=False, dtype={'LeadID': Integer, 'AccountID': Integer, 'ClientID': Integer, 'Position': String(75),
                                                                           'FirstName': String(50), 'LastName': String(50), 'Email': String(50), 'CompanyName': String(100)})
# Out:
# 0

# %%
generate_license_key()
# Out:
# '35da9c7d3af1445b981a'

# %%
test = leads_df.drop(columns='AccountID')
test
# Out:
#       LeadID                              Position First Name   Last Name  \
# 0     100000             Chief Information Officer        Bob        King
# 1     100010               Chief Operating Officer        Jim     Johnson
# 2     100020                         VP Operations    Anthony      Bezina
# 3     100030             Chief Information Officer       Adam        Kuta
# 4     100040  Senior Director, Business Technology      Irene   Valentine
# ...      ...                                   ...        ...         ...
# 1534  115340                    Technical Director     Pirkle        Mark
# 1535  115350                     Technical manager     Gunnar      Bakken
# 1536  115360                     Head of Solutions      Kamil           K
# 1537  115370                       Leiter Group IT     Stefan  Magerstedt
# 1538  115380              Chief Technology Officer  Sebastian    Traegner
#
#                            Email Unnamed: 5               CompanyName
# 0             bob.king@sandc.com        NaN      S&C Electric Company
# 1                  jim@sandc.com        NaN      S&C Electric Company
# 2       anthony.bezina@sandc.com        NaN      S&C Electric Company
# 3               akuta@mybobs.com        NaN  Bob's Discount Furniture
# 4     irene.valentine@mybobs.com        NaN  Bob's Discount Furniture
# ...                          ...        ...                       ...
# 1534                         NaN        NaN               Voith Hydro
# 1535                         NaN        NaN               Voith Hydro
# 1536                         NaN        NaN                    TRILUX
# 1537                         NaN        NaN                    TRILUX
# 1538                         NaN        NaN                    TRILUX
#
# [1539 rows x 7 columns]

# %%
a = pd.read_sql_table('Accounts', con=engine.connect())
a
# Out:
#       AccountID                        CompanyName  CompanyRevenue  \
# 0          1000                    NCH Corporation            6000
# 1          1010  Sammons Financial Group Companies             468
# 2          1020           Lexington Medical Center            3800
# 3          1030                           QuikTrip            9200
# 4          1040                          Chargebee             124
# ...         ...                                ...             ...
# 1393      14930                                JCB            4500
# 1394      14940                BAUHAUS Deutschland            8600
# 1395      14950                       Bilfinger UK            4000
# 1396      14960                         Innomotics            1500
# 1397      14970                         Breuninger            3500
#
#       EmployeeHeadCount                CompanyIndustry  \
# 0                  8500                      Chemicals
# 1                  1300             Financial Services
# 2                  8000         Hospital & Health Care
# 3                 31000                         Retail
# 4                  1110             Financial Services
# ...                 ...                            ...
# 1393                 30        Machinery Manufacturing
# 1394                 77                         Retail
# 1395                 35  IT Services and IT Consulting
# 1396                 10        Machinery Manufacturing
# 1397                 22                         Retail
#
#                                      CompanySpecialties     CompanyType  \
# 0     Production Chemicals/Manufacturing, Commercial...  Privately Held
# 1                                    Financial Services  Privately Held
# 2     Heart Center, Women's Services, Cancer Center,...       Nonprofit
# 3                                                  None  Privately Held
# 4     Recurring Billing, Subscription Management, Pa...  Privately Held
# ...                                                 ...             ...
# 1393               Construction Equipment Manufacturing  Privately Held
# 1394                                               None  Public Company
# 1395  Oil & Gas, Energy & Power, Pharmaceutical & Ch...  Privately Held
# 1396  Electric Motors, Low Voltage Motors, High Volt...  Public Company
# 1397  Fashion, Lifestyle, Premium and Luxury , Omnic...  Public Company
#
#              Country             City Timezone  ClientID
# 0      United States           Irving      EST    100000
# 1      United States  West Des Moines      EST    100000
# 2      United States    West Columbia      EST    100000
# 3      United States            Tulsa      EST    100000
# 4      United States    San Francisco      EST    100000
# ...              ...              ...      ...       ...
# 1393  United Kingdom         Rocester      GMT    100000
# 1394         Germany         Mannheim      CET    100000
# 1395  United Kingdom           London      GMT    100000
# 1396         Germany         Erlangen      CET    100000
# 1397         Germany        Stuttgart      CET    100000
#
# [1398 rows x 11 columns]

# %%
clientID = 100000

test = pd.read_sql(text(f'SELECT * FROM Accounts WHERE (ClientID={clientID})'), con=engine.connect())
test
# Out:
#       AccountID                        CompanyName  CompanyRevenue  \
# 0          1000                    NCH Corporation            6000
# 1          1010  Sammons Financial Group Companies             468
# 2          1020           Lexington Medical Center            3800
# 3          1030                           QuikTrip            9200
# 4          1040                          Chargebee             124
# ...         ...                                ...             ...
# 1393      14930                                JCB            4500
# 1394      14940                BAUHAUS Deutschland            8600
# 1395      14950                       Bilfinger UK            4000
# 1396      14960                         Innomotics            1500
# 1397      14970                         Breuninger            3500
#
#       EmployeeHeadCount                CompanyIndustry  \
# 0                  8500                      Chemicals
# 1                  1300             Financial Services
# 2                  8000         Hospital & Health Care
# 3                 31000                         Retail
# 4                  1110             Financial Services
# ...                 ...                            ...
# 1393                 30        Machinery Manufacturing
# 1394                 77                         Retail
# 1395                 35  IT Services and IT Consulting
# 1396                 10        Machinery Manufacturing
# 1397                 22                         Retail
#
#                                      CompanySpecialties     CompanyType  \
# 0     Production Chemicals/Manufacturing, Commercial...  Privately Held
# 1                                    Financial Services  Privately Held
# 2     Heart Center, Women's Services, Cancer Center,...       Nonprofit
# 3                                                  None  Privately Held
# 4     Recurring Billing, Subscription Management, Pa...  Privately Held
# ...                                                 ...             ...
# 1393               Construction Equipment Manufacturing  Privately Held
# 1394                                               None  Public Company
# 1395  Oil & Gas, Energy & Power, Pharmaceutical & Ch...  Privately Held
# 1396  Electric Motors, Low Voltage Motors, High Volt...  Public Company
# 1397  Fashion, Lifestyle, Premium and Luxury , Omnic...  Public Company
#
#              Country             City Timezone  ClientID
# 0      United States           Irving      EST    100000
# 1      United States  West Des Moines      EST    100000
# 2      United States    West Columbia      EST    100000
# 3      United States            Tulsa      EST    100000
# 4      United States    San Francisco      EST    100000
# ...              ...              ...      ...       ...
# 1393  United Kingdom         Rocester      GMT    100000
# 1394         Germany         Mannheim      CET    100000
# 1395  United Kingdom           London      GMT    100000
# 1396         Germany         Erlangen      CET    100000
# 1397         Germany        Stuttgart      CET    100000
#
# [1398 rows x 11 columns]

# %%
import sqlalchemy
query = 'SELECT * FROM Accounts WHERE (ClientID=100000)'
accounts_1 = pd.read_sql(sqlalchemy.text(query), con=engine.connect() )
leads = pd.merge(leads, accounts_df[['AccountID', 'CompanyName', 'ClientID']], on='CompanyName')
leads
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 4
#       2 query = 'SELECT * FROM Accounts WHERE (ClientID=100000)'
#       3 accounts_1 = pd.read_sql(sqlalchemy.text(query), con=engine.connect() )
# ----> 4 leads = pd.merge(leads, accounts_df[['AccountID', 'CompanyName', 'ClientID']], on='CompanyName')
#       5 leads
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['ClientID'] not in index"

# %%
l = leads_df
l = pd.merge(test, a[['AccountID', 'CompanyName']], on='CompanyName')

# %%
l
# Out:
# Empty DataFrame
# Columns: [AccountID_x, CompanyRevenue, EmployeeHeadCount, CompanyIndustry, CompanySpecialties, CompanyType, Country, City, Timezone, ClientID, AccountID_y, CompanyName]
# Index: []
